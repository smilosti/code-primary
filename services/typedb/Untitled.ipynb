# %%
import pandas as pd

# Function to clean data
def clean_data(df):
    df = df.rename(columns={
        'v4.0.12': 'ctrl_domain',
        'CLOUD CONTROLS MATRIX v4.0.12': 'ctrl_title',
        'Unnamed: 2': 'ctrl_id',
        'Unnamed: 3': 'ctrl_specification',
        'Unnamed: 4': 'ctrl_maps2_aicpa_tsc_2017_ctrls',
        'Unnamed: 5': 'ctrl_maps2_aicpa_tsc_2017_gap',
        'Unnamed: 6': 'ctrl_maps2_aicpa_tsc_2017_addendum',
        'Unnamed: 7': 'ctrl_maps2_ccm3_0_1_ctrls',
        'Unnamed: 8': 'ctrl_maps2_ccm3_0_1_gap',
        'Unnamed: 9': 'ctrl_maps2_ccm3_0_1_addendum',
        'Unnamed: 10': 'ctrl_maps2_cis_v8_0_ctrls',
        'Unnamed: 11': 'ctrl_maps2_cis_v8_0_gap',
        'Unnamed: 12': 'ctrl_maps2_cis_v8_0_addendum',
        'Unnamed: 13': 'ctrl_maps2_isf_sogp_2022_ctrls',
        'Unnamed: 14': 'ctrl_maps2_isf_sogp_2022_gap',
        'Unnamed: 15': 'ctrl_maps2_isf_sogp_2022_addendum',
        'Unnamed: 16': 'ctrl_maps2_iso_27001_2_17_18_pre2022_ctrls',
        'Unnamed: 17': 'ctrl_maps2_iso_27001_2_17_18_pre2022_gap',
        'Unnamed: 18': 'ctrl_maps2_iso_27001_2_17_18_pre2022_addendum',
        'Unnamed: 19': 'ctrl_maps2_iso_27001_2_2022_ctrls',
        'Unnamed: 20': 'ctrl_maps2_iso_27001_2_2022_gap',
        'Unnamed: 21': 'ctrl_maps2_iso_27001_2_2022_addendum',
        'Unnamed: 22': 'ctrl_maps2_nist_800_r5_ctrls',
        'Unnamed: 23': 'ctrl_maps2_nist_800_r5_gap',
        'Unnamed: 24': 'ctrl_maps2_nist_800_r5_addendum',
        'Unnamed: 25': 'ctrl_maps2_nist_csf_v1_1_ctrls',
        'Unnamed: 26': 'ctrl_maps2_nist_csf_v1_1_gap',
        'Unnamed: 27': 'ctrl_maps2_nist_csf_v1_1_addendum',
        'Unnamed: 28': 'ctrl_maps2_nist_csf_v2_0_ctrls',
        'Unnamed: 29': 'ctrl_maps2_nist_csf_v2_0_gap',
        'Unnamed: 30': 'ctrl_maps2_nist_csf_v2_0_addendum',
        'Unnamed: 31': 'ctrl_maps2_pci_dss_v3_2_1_ctrls',
        'Unnamed: 32': 'ctrl_maps2_pci_dss_v3_2_1_gap',
        'Unnamed: 33': 'ctrl_maps2_pci_dss_v3_2_1_addendum',
        'Unnamed: 34': 'ctrl_maps2_pci_dss_v4_0_ctrls',
        'Unnamed: 35': 'ctrl_maps2_pci_dss_v4_0_gap',
        'Unnamed: 36': 'ctrl_maps2_pci_dss_v4_0_addendum',
    })
    return df

# Load the Excel file
df = pd.read_excel(r'/workspaces/code/services/typedb/ccm_v4_0_12.xlsx', sheet_name=4)

# Clean the data
df_clean = clean_data(df.copy())
# Display first 10 rows
df_clean.head(10)
# Out:
#                               ctrl_domain  \
# 0                                     NaN
# 1                          Control Domain
# 2                 Audit & Assurance - A&A
# 3                       Audit & Assurance
# 4                       Audit & Assurance
# 5                       Audit & Assurance
# 6                       Audit & Assurance
# 7                       Audit & Assurance
# 8                       Audit & Assurance
# 9  Application & Interface Security - AIS
#
#                                   ctrl_title     ctrl_id  \
# 0                                        NaN         NaN
# 1                              Control Title  Control ID
# 2                                        NaN         NaN
# 3  Audit and Assurance Policy and Procedures      A&A-01
# 4                    Independent Assessments      A&A-02
# 5             Risk Based Planning Assessment      A&A-03
# 6                    Requirements Compliance      A&A-04
# ...
