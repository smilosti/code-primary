# %% [markdown]
# Extend the Schema for CCM v4.0.12 and include relevan sheets.

# %%
from typedb.driver import TypeDB, SessionType, TransactionType

def extend_schema_with_csa():
    with TypeDB.core_driver("localhost:1729") as driver:
        with driver.session("grc_matrix", SessionType.SCHEMA) as session:
            with session.transaction(TransactionType.WRITE) as transaction:
                schema_extension_query = '''
                define
                ccm_v4_0_12_audit_guidelines sub CSAFramework,
                    owns ccm4_0_12_ctrl_domain,
                    owns ccm4_0_12_ctrl_title,
                    owns ccm4_0_12_ctrl_id,
                    owns ccm4_0_12_ctrl_specification,
                    owns ccm4_0_12_ctrl_auditing_guidelines;

                ccm_v4_0_12_caiq_reqs sub CSAFramework,
                    owns ccm4_0_12_ctrl_domain,
                    owns ccm4_0_12_ctrl_title,
                    owns ccm4_0_12_ctrl_id,
                    owns ccm4_0_12_ctrl_specification,
                    owns ccm4_0_12_ctrl_question_id,
                    owns ccm4_0_12_ctrl_consensus_assessments_question,
                    owns ccm4_0_12_ctrl_caiq_lite;

                ccm_v4_0_12_ccm sub CSAFramework,
                    owns ccm4_0_12_ctrl_domain,
                    owns ccm4_0_12_ctrl_title,
                    owns ccm4_0_12_ctrl_id,
                    owns ccm4_0_12_ctrl_specification,
                    owns ccm4_0_12_ccm_lite,
                    owns ccm4_0_12_applicable_ownership_iaas,
                    owns ccm4_0_12_applicable_ownership_paas,
                    owns ccm4_0_12_applicable_ownership_saas,
                    owns ccm4_0_12_architectural_relevance_phys,
                    owns ccm4_0_12_architectural_relevance_network,
                    owns ccm4_0_12_architectural_relavance_data,
                    owns ccm4_0_12_organizational_relevance_cybersecurity,
                    owns ccm4_0_12_organizational_relevance_internal_audit,
                    owns ccm4_0_12_organizational_relevance_architecture_team,
                    owns ccm4_0_12_organizational_relevance_sw_development,
                    owns ccm4_0_12_organizational_relevance_operations,
                    owns ccm4_0_12_organizational_relevance_legal_privacy,
                    owns ccm4_0_12_organizational_relevance_grc_team,
                    owns ccm4_0_12_organizational_relevance_supply_chain_management,
                    owns ccm4_0_12_organizational_relevance_hr;

                ccm_v4_0_12_implmnt_guidelines sub CSAFramework,
                    owns ccm4_0_12_ctrl_domain,
                    owns ccm4_0_12_ctrl_title,
                    owns ccm4_0_12_ctrl_id,
                    owns ccm4_0_12_ctrl_specification,
                    owns ccm4_0_12_ctrl_ownership_iaas,
                    owns ccm4_0_12_ctrl_ownership_paas,
                    owns ccm4_0_12_ctrl_ownership_saas,
                    owns ccm4_0_12_ctrl_implentation_guidelines_csp,
                    owns ccm4_0_12_ctrl_implentation_guidelines_csc;

                ccm_v4_0_12_scope_applic_mappings sub CSAFramework,
                    owns ccm4_0_12_ctrl_domain,
                    owns ccm4_0_12_ctrl_title,
                    owns ccm4_0_12_ctrl_id,
                    owns ccm4_0_12_ctrl_specification,
                    owns ccm4_0_12_ctrl_maps2_aicpa_2017_ctrls,
                    owns ccm4_0_12_ctrl_maps2_aicpa_2017_gap_level,
                    owns ccm4_0_12_ctrl_maps2_aicpa_2017_addendum,
                    owns ccm4_0_12_ctrl_maps2_ccmv3_0_1_ctrls,
                    owns ccm4_0_12_ctrl_maps2_ccmv3_0_1_gap_level,
                    owns ccm4_0_12_ctrl_maps2_ccmv3_0_1_addendum,
                    owns ccm4_0_12_ctrl_maps2_nist_csf_1_1_addendum,
                    owns ccm4_0_12_ctrl_maps2_nist_csf_2_0_ctrls,
                    owns ccm4_0_12_ctrl_maps2_nist_csf_2_0_gap_level,
                    owns ccm4_0_12_ctrl_maps2_nist_csf_2_0_addendum,
                    owns ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_ctrls,
                    owns ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_gap_level,
                    owns ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_addendum,
                    owns ccm4_0_12_ctrl_maps2_pci_dss_v4_0_ctrls,
                    owns ccm4_0_12_ctrl_maps2_pci_dss_v4_0_gap_level,
                    owns ccm4_0_12_ctrl_maps2_pci_dss_v4_0_addendum;

                ccm4_0_12_ctrl_domain sub attribute, value string;
                ccm4_0_12_ctrl_title sub attribute, value string;
                ccm4_0_12_ctrl_id sub attribute, value string;
                ccm4_0_12_ctrl_specification sub attribute, value string;
                ccm4_0_12_ctrl_auditing_guidelines sub attribute, value string;
                ccm4_0_12_ctrl_question_id sub attribute, value string;
                ccm4_0_12_ctrl_consensus_assessments_question sub attribute, value string;
                ccm4_0_12_ctrl_caiq_lite sub attribute, value string;
                ccm4_0_12_ccm_lite sub attribute, value string;
                ccm4_0_12_applicable_ownership_iaas sub attribute, value string;
                ccm4_0_12_applicable_ownership_paas sub attribute, value string;
                ccm4_0_12_applicable_ownership_saas sub attribute, value string;
                ccm4_0_12_architectural_relevance_phys sub attribute, value string;
                ccm4_0_12_architectural_relevance_network sub attribute, value string;
                ccm4_0_12_architectural_relavance_data sub attribute, value string;
                ccm4_0_12_organizational_relevance_cybersecurity sub attribute, value string;
                ccm4_0_12_organizational_relevance_internal_audit sub attribute, value string;
                ccm4_0_12_organizational_relevance_architecture_team sub attribute, value string;
                ccm4_0_12_organizational_relevance_sw_development sub attribute, value string;
                ccm4_0_12_organizational_relevance_operations sub attribute, value string;
                ccm4_0_12_organizational_relevance_legal_privacy sub attribute, value string;
                ccm4_0_12_organizational_relevance_grc_team sub attribute, value string;
                ccm4_0_12_organizational_relevance_supply_chain_management sub attribute, value string;
                ccm4_0_12_organizational_relevance_hr sub attribute, value string;
                ccm4_0_12_ctrl_ownership_iaas sub attribute, value string;
                ccm4_0_12_ctrl_ownership_paas sub attribute, value string;
                ccm4_0_12_ctrl_ownership_saas sub attribute, value string;
                ccm4_0_12_ctrl_implentation_guidelines_csp sub attribute, value string;
                ccm4_0_12_ctrl_implentation_guidelines_csc sub attribute, value string;
                ccm4_0_12_ctrl_maps2_aicpa_2017_ctrls sub attribute, value string;
                ccm4_0_12_ctrl_maps2_aicpa_2017_gap_level sub attribute, value string;
                ccm4_0_12_ctrl_maps2_aicpa_2017_addendum sub attribute, value string;
                ccm4_0_12_ctrl_maps2_ccmv3_0_1_ctrls sub attribute, value string;
                ccm4_0_12_ctrl_maps2_ccmv3_0_1_gap_level sub attribute, value string;
                ccm4_0_12_ctrl_maps2_ccmv3_0_1_addendum sub attribute, value string;
                ccm4_0_12_ctrl_maps2_nist_csf_1_1_addendum sub attribute, value string;
                ccm4_0_12_ctrl_maps2_nist_csf_2_0_ctrls sub attribute, value string;
                ccm4_0_12_ctrl_maps2_nist_csf_2_0_gap_level sub attribute, value string;
                ccm4_0_12_ctrl_maps2_nist_csf_2_0_addendum sub attribute, value string;
                ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_ctrls sub attribute, value string;
                ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_gap_level sub attribute, value string;
                ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_addendum sub attribute, value string;
                ccm4_0_12_ctrl_maps2_pci_dss_v4_0_ctrls sub attribute, value string;
                ccm4_0_12_ctrl_maps2_pci_dss_v4_0_gap_level sub attribute, value string;
                ccm4_0_12_ctrl_maps2_pci_dss_v4_0_addendum sub attribute, value string;
                '''
                transaction.query.define(schema_extension_query)
                transaction.commit()
                print("Schema extended with CSAFramework entities successfully.")

extend_schema_with_csa()
# Out:
# Schema extended with CSAFramework entities successfully.

# %% [markdown]
# Data insertion for each file.

# %%
import pandas as pd
from typedb.driver import TypeDB, SessionType, TransactionType

# Load CSV data
file_path_scope = '/workspaces/code/services/typedb/ccm_v4_0_12_scope_applic_mappings.csv'
df_scope = pd.read_csv(file_path_scope)

def escape_string(value):
    if pd.isna(value):
        return ""
    return value.replace('"', '\\"')

def insert_scope_applic_mappings():
    with TypeDB.core_driver("localhost:1729") as driver:
        with driver.session("grc_matrix", SessionType.DATA) as session:
            with session.transaction(TransactionType.WRITE) as transaction:
                for index, row in df_scope.iterrows():
                    scope_query = f'''
                    insert
                        $scope isa ccm_v4_0_12_scope_applic_mappings,
                            has ccm4_0_12_ctrl_domain "{escape_string(row['ccm4_0_12_ctrl_domain'])}",
                            has ccm4_0_12_ctrl_title "{escape_string(row['ccm4_0_12_ctrl_title'])}",
                            has ccm4_0_12_ctrl_id "{escape_string(row['ccm4_0_12_ctrl_id'])}",
                            has ccm4_0_12_ctrl_specification "{escape_string(row['ccm4_0_12_ctrl_specification'])}",
                            has ccm4_0_12_ctrl_maps2_aicpa_2017_ctrls "{escape_string(row['ccm4_0_12_ctrl_maps2_aicpa_2017_ctrls'])}",
                            has ccm4_0_12_ctrl_maps2_aicpa_2017_gap_level "{escape_string(row['ccm4_0_12_ctrl_maps2_aicpa_2017_gap_level'])}",
                            has ccm4_0_12_ctrl_maps2_aicpa_2017_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_aicpa_2017_addendum'])}",
                            has ccm4_0_12_ctrl_maps2_ccmv3_0_1_ctrls "{escape_string(row['ccm4_0_12_ctrl_maps2_ccmv3_0_1_ctrls'])}",
                            has ccm4_0_12_ctrl_maps2_ccmv3_0_1_gap_level "{escape_string(row['ccm4_0_12_ctrl_maps2_ccmv3_0_1_gap_level'])}",
                            has ccm4_0_12_ctrl_maps2_ccmv3_0_1_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_ccmv3_0_1_addendum'])}",
                            has ccm4_0_12_ctrl_maps2_nist_csf_1_1_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_nist_csf_1_1_addendum'])}",
                            has ccm4_0_12_ctrl_maps2_nist_csf_2_0_ctrls "{escape_string(row['ccm4_0_12_ctrl_maps2_nist_csf_2_0_ctrls'])}",
                            has ccm4_0_12_ctrl_maps2_nist_csf_2_0_gap_level "{escape_string(row['ccm4_0_12_ctrl_maps2_nist_csf_2_0_gap_level'])}",
                            has ccm4_0_12_ctrl_maps2_nist_csf_2_0_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_nist_csf_2_0_addendum'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_ctrls "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_ctrls'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_gap_level "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_gap_level'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_addendum'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v4_0_ctrls "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v4_0_ctrls'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v4_0_gap_level "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v4_0_gap_level'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v4_0_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v4_0_addendum'])}";
                    '''
                    transaction.query.insert(scope_query)
                transaction.commit()
                print("Data inserted successfully for ccm_v4_0_12_scope_applic_mappings.")

insert_scope_applic_mappings()
# Out:
# Data inserted successfully for ccm_v4_0_12_scope_applic_mappings.

# %%
import pandas as pd
from typedb.driver import TypeDB, SessionType, TransactionType

# Load CSV data
file_path_caiq = '/workspaces/code/services/typedb/ccm_v4_0_12_caiq_reqs.csv'
df_caiq = pd.read_csv(file_path_caiq)

def escape_string(value):
    if pd.isna(value):
        return ""
    return value.replace('"', '\\"')

def insert_caiq_reqs():
    with TypeDB.core_driver("localhost:1729") as driver:
        with driver.session("grc_matrix", SessionType.DATA) as session:
            with session.transaction(TransactionType.WRITE) as transaction:
                for index, row in df_caiq.iterrows():
                    caiq_query = f'''
                    insert
                        $caiq isa ccm_v4_0_12_caiq_reqs,
                            has ccm4_0_12_ctrl_domain "{escape_string(row['ccm4_0_12_ctrl_domain'])}",
                            has ccm4_0_12_ctrl_title "{escape_string(row['ccm4_0_12_ctrl_title'])}",
                            has ccm4_0_12_ctrl_id "{escape_string(row['ccm4_0_12_ctrl_id'])}",
                            has ccm4_0_12_ctrl_specification "{escape_string(row['ccm4_0_12_ctrl_specification'])}",
                            has ccm4_0_12_ctrl_question_id "{escape_string(row['ccm4_0_12_ctrl_question_id'])}",
                            has ccm4_0_12_ctrl_consensus_assessments_question "{escape_string(row['ccm4_0_12_ctrl_consensus_assessments_question'])}",
                            has ccm4_0_12_ctrl_caiq_lite "{escape_string(row['ccm4_0_12_ctrl_caiq_lite'])}";
                    '''
                    transaction.query.insert(caiq_query)
                transaction.commit()
                print("Data inserted successfully for ccm_v4_0_12_caiq_reqs.")

insert_caiq_reqs()
# Out:
# Data inserted successfully for ccm_v4_0_12_caiq_reqs.

# %%
file_path_ccm = '/workspaces/code/services/typedb/ccm_v4_0_12_ccm.csv'
df_ccm = pd.read_csv(file_path_ccm)

def escape_string(value):
    if pd.isna(value):
        return ""
    return value.replace('"', '\\"')

def insert_ccm():
    with TypeDB.core_driver("localhost:1729") as driver:
        with driver.session("grc_matrix", SessionType.DATA) as session:
            with session.transaction(TransactionType.WRITE) as transaction:
                for index, row in df_ccm.iterrows():
                    ccm_query = f'''
                    insert
                        $ccm isa ccm_v4_0_12_ccm,
                            has ccm4_0_12_ctrl_domain "{row['ccm4_0_12_ctrl_domain']}",
                            has ccm4_0_12_ctrl_title "{row['ccm4_0_12_ctrl_title']}",
                            has ccm4_0_12_ctrl_id "{row['ccm4_0_12_ctrl_id']}",
                            has ccm4_0_12_ctrl_specification "{row['ccm4_0_12_ctrl_specification']}",
                            has ccm4_0_12_ccm_lite "{row['ccm4_0_12_ccm_lite']}",
                            has ccm4_0_12_applicable_ownership_iaas "{row['ccm4_0_12_applicable_ownership_iaas']}",
                            has ccm4_0_12_applicable_ownership_paas "{row['ccm4_0_12_applicable_ownership_paas']}",
                            has ccm4_0_12_applicable_ownership_saas "{row['ccm4_0_12_applicable_ownership_saas']}",
                            has ccm4_0_12_architectural_relevance_phys "{row['ccm4_0_12_architectural_relevance_phys']}",
                            has ccm4_0_12_architectural_relevance_network "{row['ccm4_0_12_architectural_relevance_network']}",
                            has ccm4_0_12_architectural_relavance_data "{row['ccm4_0_12_architectural_relavance_data']}",
                            has ccm4_0_12_organizational_relevance_cybersecurity "{row['ccm4_0_12_organizational_relevance_cybersecurity']}",
                            has ccm4_0_12_organizational_relevance_internal_audit "{row['ccm4_0_12_organizational_relevance_internal_audit']}",
                            has ccm4_0_12_organizational_relevance_architecture_team "{row['ccm4_0_12_organizational_relevance_architecture_team']}",
                            has ccm4_0_12_organizational_relevance_sw_development "{row['ccm4_0_12_organizational_relevance_sw_development']}",
                            has ccm4_0_12_organizational_relevance_operations "{row['ccm4_0_12_organizational_relevance_operations']}",
                            has ccm4_0_12_organizational_relevance_legal_privacy "{row['ccm4_0_12_organizational_relevance_legal_privacy']}",
                            has ccm4_0_12_organizational_relevance_grc_team "{row['ccm4_0_12_organizational_relevance_grc_team']}",
                            has ccm4_0_12_organizational_relevance_supply_chain_management "{row['ccm4_0_12_organizational_relevance_supply_chain_management']}",
                            has ccm4_0_12_organizational_relevance_hr "{row['ccm4_0_12_organizational_relevance_hr']}";
                    '''
                    transaction.query.insert(ccm_query)
                transaction.commit()
                print("Data inserted successfully for ccm_v4_0_12_ccm.")

insert_ccm()
# Out:
# Data inserted successfully for ccm_v4_0_12_ccm.

# %%
import pandas as pd
from typedb.driver import TypeDB, SessionType, TransactionType

# Load CSV data
file_path_implmnt = '/workspaces/code/services/typedb/ccm_v4_0_12_implmnt_guidlines.csv'
df_implmnt = pd.read_csv(file_path_implmnt)

def escape_string(value):
    if pd.isna(value):
        return ""
    return value.replace('"', '\\"').replace('\n', '\\n').replace('\r', '\\r')

def insert_implmnt_guidelines():
    with TypeDB.core_driver("localhost:1729") as driver:
        with driver.session("grc_matrix", SessionType.DATA) as session:
            with session.transaction(TransactionType.WRITE) as transaction:
                for index, row in df_implmnt.iterrows():
                    implmnt_query = f'''
                    insert
                        $implmnt isa ccm_v4_0_12_implmnt_guidelines,
                            has ccm4_0_12_ctrl_domain "{escape_string(row['ccm4_0_12_ctrl_domain'])}",
                            has ccm4_0_12_ctrl_title "{escape_string(row['ccm4_0_12_ctrl_title'])}",
                            has ccm4_0_12_ctrl_id "{escape_string(row['ccm4_0_12_ctrl_id'])}",
                            has ccm4_0_12_ctrl_specification "{escape_string(row['ccm4_0_12_ctrl_specification'])}",
                            has ccm4_0_12_ctrl_ownership_iaas "{escape_string(row['ccm4_0_12_ctrl_ownership_iaas'])}",
                            has ccm4_0_12_ctrl_ownership_paas "{escape_string(row['ccm4_0_12_ctrl_ownership_paas'])}",
                            has ccm4_0_12_ctrl_ownership_saas "{escape_string(row['ccm4_0_12_ctrl_ownership_saas'])}",
                            has ccm4_0_12_ctrl_implentation_guidelines_csp "{escape_string(row['ccm4_0_12_ctrl_implentation_guidelines_csp'])}",
                            has ccm4_0_12_ctrl_implentation_guidelines_csc "{escape_string(row['ccm4_0_12_ctrl_implentation_guidelines_csc'])}";
                    '''
                    transaction.query.insert(implmnt_query)
                transaction.commit()
                print("Data inserted successfully for ccm_v4_0_12_implmnt_guidelines.")

insert_implmnt_guidelines()
# Out:
# Data inserted successfully for ccm_v4_0_12_implmnt_guidelines.

# %%
import pandas as pd
from typedb.driver import TypeDB, SessionType, TransactionType

# Load CSV data
file_path_scope = '/workspaces/code/services/typedb/ccm_v4_0_12_scope_applic_mappings.csv'
df_scope = pd.read_csv(file_path_scope)

def escape_string(value):
    if pd.isna(value):
        return ""
    return value.replace('"', '\\"').replace('\n', '\\n').replace('\r', '\\r')

def insert_scope_applic_mappings():
    with TypeDB.core_driver("localhost:1729") as driver:
        with driver.session("grc_matrix", SessionType.DATA) as session:
            with session.transaction(TransactionType.WRITE) as transaction:
                for index, row in df_scope.iterrows():
                    scope_query = f'''
                    insert
                        $scope isa ccm_v4_0_12_scope_applic_mappings,
                            has ccm4_0_12_ctrl_domain "{escape_string(row['ccm4_0_12_ctrl_domain'])}",
                            has ccm4_0_12_ctrl_title "{escape_string(row['ccm4_0_12_ctrl_title'])}",
                            has ccm4_0_12_ctrl_id "{escape_string(row['ccm4_0_12_ctrl_id'])}",
                            has ccm4_0_12_ctrl_specification "{escape_string(row['ccm4_0_12_ctrl_specification'])}",
                            has ccm4_0_12_ctrl_maps2_aicpa_2017_ctrls "{escape_string(row['ccm4_0_12_ctrl_maps2_aicpa_2017_ctrls'])}",
                            has ccm4_0_12_ctrl_maps2_aicpa_2017_gap_level "{escape_string(row['ccm4_0_12_ctrl_maps2_aicpa_2017_gap_level'])}",
                            has ccm4_0_12_ctrl_maps2_aicpa_2017_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_aicpa_2017_addendum'])}",
                            has ccm4_0_12_ctrl_maps2_ccmv3_0_1_ctrls "{escape_string(row['ccm4_0_12_ctrl_maps2_ccmv3_0_1_ctrls'])}",
                            has ccm4_0_12_ctrl_maps2_ccmv3_0_1_gap_level "{escape_string(row['ccm4_0_12_ctrl_maps2_ccmv3_0_1_gap_level'])}",
                            has ccm4_0_12_ctrl_maps2_ccmv3_0_1_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_ccmv3_0_1_addendum'])}",
                            has ccm4_0_12_ctrl_maps2_nist_csf_1_1_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_nist_csf_1_1_addendum'])}",
                            has ccm4_0_12_ctrl_maps2_nist_csf_2_0_ctrls "{escape_string(row['ccm4_0_12_ctrl_maps2_nist_csf_2_0_ctrls'])}",
                            has ccm4_0_12_ctrl_maps2_nist_csf_2_0_gap_level "{escape_string(row['ccm4_0_12_ctrl_maps2_nist_csf_2_0_gap_level'])}",
                            has ccm4_0_12_ctrl_maps2_nist_csf_2_0_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_nist_csf_2_0_addendum'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_ctrls "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_ctrls'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_gap_level "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_gap_level'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v3_2_1_addendum'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v4_0_ctrls "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v4_0_ctrls'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v4_0_gap_level "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v4_0_gap_level'])}",
                            has ccm4_0_12_ctrl_maps2_pci_dss_v4_0_addendum "{escape_string(row['ccm4_0_12_ctrl_maps2_pci_dss_v4_0_addendum'])}";
                    '''
                    transaction.query.insert(scope_query)
                transaction.commit()
                print("Data inserted successfully for ccm_v4_0_12_scope_applic_mappings.")

insert_scope_applic_mappings()
# Out:
# Data inserted successfully for ccm_v4_0_12_scope_applic_mappings.
